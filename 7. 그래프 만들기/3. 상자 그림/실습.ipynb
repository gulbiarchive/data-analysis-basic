# %%
import pandas as pd
import seaborn as sns

mpg = pd.read_csv('mpg.csv')

# %%
car_3 = mpg.query('category in ["compcat", "subcompact", "suv"]')

sns.boxplot(data=car_3, x='category', y='cty')
# Out:
# <Axes: xlabel='category', ylabel='cty'>
