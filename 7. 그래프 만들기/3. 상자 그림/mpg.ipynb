# %%
import pandas as pd
import seaborn as sns

mpg = pd.read_csv('mpg.csv')

# %%
# sns.boxplot() : 상자 그림 만들기

# x축 drv, y축 hwy
# 구동 방식별 고속도로 연비
sns.boxplot(data=mpg, x='drv', y='hwy')
# Out:
# <Axes: xlabel='drv', ylabel='hwy'>
